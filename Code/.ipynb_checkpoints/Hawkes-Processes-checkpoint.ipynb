# %%
# %matplotlib inline
import sys
from collections import defaultdict, Counter
import networkx as nx
import numpy as np
import pylab as plt
import math
from itertools import chain
#import matplotlib.cm as cm
import statsmodels.api as sm
from os import listdir
from scipy.stats.stats import pearsonr
import json
import random
import itertools
from copy import deepcopy
import time
import scipy as sp
from scipy.sparse import csr_matrix
from scipy.stats import entropy
import matplotlib.cm as cm
from numpy.random import choice
import itertools
from sklearn import manifold
import operator
import itertools
from datetime import datetime as dt
import matplotlib.mlab as mlab
from scipy.stats import norm
import re
from scipy import stats
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats.mstats import zscore

# %% [markdown]
#  Import Hawkes python module and the content will be in a subfolder labeled hawkes:
# https://github.com/stmorse/hawkes

# %%
import sys
sys.path.append('hawkes/')
from MHP import MHP

# %% [markdown]
# ### Load Time series
# Hawkes only looks at the events at the same time series

# %%
#1. Load DSDE jobs, and select skills that are in WoS
J={}
with open('time_series1.txt','r', encoding ='latin') as f:
    for line in f:
        skill=line.split('[')[0].strip().lower() # extract skill
        vs=line.split('[')[1].split(']')[0].split(',') # vector : extract years + frequency - all content split by commas
        dic=dict((int(i.split(':')[0]),int(i.split(':')[1])) for i in vs) # split year and freq
        # KEY is skill, VALUE is year, freq 
        J[skill]=dic

# %% [markdown]
# ### Data Transformation
# Run this block to replace zero frequencies by 0.00001

# %%
#JOBS
JW={}
for i in J:
    JW[i] = J[i]

# %%
### Add non-zero values
for key, value in JW.items():

    for i in JW[key]:
        if JW[key][i]==0:
            JW[key][i]=0.00001

# %%
#3.  split J by year and find total per year
## JOB DATA TRANSFORMATION USE JW
JT=defaultdict(int) # initializing first dictionary for collection/list
for i in JW:
    for year in JW[i]:
        JT[year]+=JW[i][year]

JN={}
for i in JW:
    dic=dict((k,v/float(JT[k])) for k,v in JW[i].items() if 2010<=k<=2016 and v!=0)#if 2010<=k<=2016 and v!=0 ) 

    if len(dic)==7:
        JN[i]=dic

# %%
# total frequencies per skills for influence graph
JS=defaultdict(int)
for i in J:
    for year in J[i]:
       # JS[i]+=float(str(round(J[i][year],0)))
        JS[i]+=int(J[i][year])

# %% [markdown]
# ### TOP Frequency Skills
# We select to 50 skills (words) by frequency that will be used in Hawkes process

# %%
#select top DSDE skills (top 50 still Bursing skills )
N=50

topSkills=sorted(list(zip(*sorted([(k,v) for k,v in J.items()],key=lambda x:-sum(x[1].values()))))[0][:N])

# %%
DSDE=dict((k,v) for k,v in JN.items() if k in topSkills)
DSDE1={}
for s in DSDE:
    dic=DSDE[s]
    t=sum(dic.values())
    DSDE1[s]=dict((k,v/t) for k,v in dic.items())

# %% [markdown]
# ## Hawkes Process
#
# Read - Steven Morse blog and thesis - https://stmorse.github.io/journal/Hawkes-python.html
#
# From personal communication with Steven:
#
# "The MHP.generate_seq() method returns an array with shape (N, 2), each row an event, col 0 is time, col 1 is the label of the sequence where it occurred.  If you have already run generate_seq(), you should be able to then call EM() and get estimated parameters, EM() uses the same format and the data is saved as a variable of that class instance."

# %%
# simulate data for Hawkes Process estimation 
n=10# expanding 
Seq=[]
skills=DSDE1.keys()
nSkills=len(skills)
for year in range(2010,2017):
   # print(year)
    for i in range(n):
       # print(i)
        ps=[DSDE1[s][year] for s in skills]
       # print(len(ps))
       # print(ps)
        rp=np.random.uniform(0,1,len(ps))
       # print(rp)
        seq=(rp<ps).astype(int)
       # print(seq)
        Seq.append(seq)
Seq=np.array(Seq)
for i in range(Seq.shape[1]):
    v=Seq[:,i]
    v[v==1]=i+1
td=[]
t=0
#print(len(Seq))

for i in Seq:
   #print(i)
    for j in i:
        t+=random.random()
        if j!=0:
            td.append([t,j])
          # print(t,j)
       # else:
           # print(j)
td=np.array(td)
td[:,1]-=1

# %%
#TEST

# simulate data for Hawke Process estimation 
n=10# expanding 
Seq=[]
skills=DSDETest.keys()
nSkills=len(skills)
for year in range(2010,2017):
   # print(year)
    for i in range(n):
       # print(i)
        ps=[DSDETest[s][year] for s in skills]
       # print(len(ps))
       # print(ps)
        rp=np.random.uniform(0,1,len(ps))
       # print(rp)
        seq=(rp<ps).astype(int)
       # print(seq)
        Seq.append(seq)
Seq=np.array(Seq)
for i in range(Seq.shape[1]):
    v=Seq[:,i]
    v[v==1]=i+1
td=[]
t=0
#print(len(Seq))

for i in Seq:
   #print(i)
    for j in i:
        t+=random.random()
        if j!=0:
            td.append([t,j])
          # print(t,j)
       # else:
           # print(j)
td=np.array(td)
td[:,1]-=1

# %%
# initialization models 

mhat = np.random.uniform(0,1, size=nSkills)
ahat = np.random.uniform(0,1, size=(nSkills,nSkills))
w = 3
P = MHP(mu=mhat, alpha=ahat, omega=w)
#P.generate_seq(60)
P.data=td
#P.plot_events()
len(P.data)
# Out:
# Max eigenvalue: 24.66915
# (WARNING) Unstable.
# 455

# %%
start=time.time()
M=P.EM(ahat, mhat, w)[0]
duration=time.time()-start
duration
# Out:
# After ITER 0 (old: -10000.000 new: -1.110)
#  terms -454.9621, 404.8030, 50.1970
# After ITER 10 (old: -1.110 new: -4.894)
#  terms -2100.3062, 328.6592, 126.3408
# Reached stopping criterion. (Old: -4.894 New: -4.895)
# 2.773644208908081

# %% [markdown]
# ## Influence Graph
# We need to undersdand this process better.

# %%
#construct influence graph 
mM=np.mean(M)
G=nx.from_numpy_matrix(M>mM) # Return a graph from numpy matrix.
mapping=dict(zip(range(nSkills),skills))
H=nx.relabel_nodes(G,mapping)
pos=nx.spring_layout(H)

# %%
#H.edges()
#H.nodes()

# %%
f = open('CausalityNetworkEdges-06-20.txt', "w")
for i,j in H.edges():
    f.write(str(i)+'\t' +str(j)+ '\n')
f.close()

# %%
soft_skills=['Analytical Skills','Apple iWork','Apple Numbers','Arabic','Articulate','Basic Internet Skills',
      'Bilingual','Building Effective Relationships','Business Presentations','Chinese','Communication Skills',
      'Computer Skills','Creative Problem Solving','Creativity','Critical Thinking','Decision Making',
      'Detail-Oriented','Editing','Energetic','English','French','German','Hebrew','Independent Thinking','Initiative',
      'Japanese','Korean','Latin','Leadership','Management','Meeting Deadlines','Meeting Planning/Facilitation',
      'Mentoring','Microsoft Excel','Microsoft Office','Microsoft Outlook','Microsoft Powerpoint','Microsoft Windows',
      'Microsoft Word','Multi-Tasking','Needs Assessment','Notepad','Online Research','Organizational Skills',
      'Performance Analysis','Persuasion','Planning','Polish','Portuguese','Positive Disposition','Preparing Reports',
      'Presentation Skills','Preventive Maintenance','Prioritizing Tasks','Problem Solving','Progress Reports',
      'Project Planning and Development Skills','Quality Assurance and Control','Quick Learner','Research','Russian',
      'Self-Motivation','Self-Starter','Service Improvement','Spanish','Strategic Planning','Strategic Thinking','Swedish',
      'Team Building','Team Work/ Collaboration','Technical Assistance','Telephone Skills',
      'Timelines','Time Management','Tool Selection','Troubleshooting','Typing','Work Area Maintenance','Writing']

# %%
soft =[x.lower() for x in soft_skills]

# %%
f = open('CausalityNetworkNodePosFreqSkill-06-20.txt', "w")
for i in pos:
    if i in soft:
        print(i)
        skill = 'soft'
    else:
        skill = 'hard'
    freq = JS[i]
    f.write(str(i)+'\t' +str(pos[i][0])+'\t' +str(pos[i][1])+'\t'+ skill +'\t'+ str(freq) + '\n')
f.close()
# Out:
# writing
# english
# meeting deadlines
# mentoring
# microsoft office
# microsoft word
# organizational skills
# planning
# time management
# troubleshooting

# %%
total = sum(JS.values())

# %%
freq=[]
for i in pos:
   # print(i)
   # print(pos[i])
   # print(JS[i])
    f = JS[i]
    freq.append(f)
   # print(f,i)

# %%
s = sum(freq)
total = []
for i in freq:
    t = i/s
    total.append(t)

# %%
fig = plt.figure(figsize=(10, 10),facecolor='white')
n=0
for i in pos:
    x,y=pos[i]
   # s = freq[i]#[20*2**n for n in range(len(x))]
    if i in soft:
        plt.scatter(x,y,total[n]*10000,alpha=0.5,facecolor='green',edgecolor='none') #=100
    else:
        plt.scatter(x,y,total[n]*10000,alpha=0.5,facecolor='blue',edgecolor='none')
    if i in soft:
        plt.text(x,y,i,ha='center',size=20)
    else:
        plt.text(x,y,i,ha='center',size=11)
    n+=1
for i,j in H.edges():
    xi,yi=pos[i]
    xj,yj=pos[j]
    plt.annotate("",
                xy=(xi, yi), xycoords='data',
                xytext=(xj, yj), textcoords='data',
                size=15,
                arrowprops=dict(arrowstyle="<|-", #linestyle="dashed",
                                color="0.3",
                                alpha=0.3,
                                shrinkA=5, shrinkB=5,
                                patchA=None,
                                patchB=None,
                                #connectionstyle='angle3,angleA=90,angleB=0',
                                ),zorder=1
                )
plt.axis('off')
#plt.savefig('causalityNetwork-burst-frequency-Jobs-directions-06-19.png',bbox_inches='tight',pad_inches=0)
# Out:
# (-0.059004256074201962,
#  1.0667481872132656,
#  -0.062061816526949538,
#  1.0434869584709598)

# %%
def plot_events(self, horizon=-1, showDays=True, labeled=True):

        if horizon < 0:
            horizon = np.amax(self.data[:,0])

 #       fig = plt.figure(figsize=(10,2))
        fig = plt.figure(figsize=(10,10))
        ax = plt.gca()
        for i in range(self.dim):
            subseq = self.data[self.data[:,1]==i][:,0]
            plt.plot(subseq, np.zeros(len(subseq)) - i, 'bo', alpha=0.2)

        if showDays:
            for j in range(1,int(horizon)):
                plt.xlim(2010,2016)
               # plt.plot([j,j], [-self.dim, 1], 'k:', alpha=0.15)

        
        if labeled:
           # SE=Jburst.keys()#[]
           # with open('/Users/olgascrivner/Documents/CNS/Burning Glass/LIngfei/top50JOBS.txt','r', encoding = 'latin') as f:
            #    for line in f:
             #       line=line.strip().split('\r')
             #       SE.append(line[0].lower())
            ax.set_yticklabels('')
            ax.set_yticks(-np.arange(0, self.dim), minor=True)
 #           ax.set_yticklabels([r'$e_{%d}$' % i for i in range(self.dim)], minor=True)
            ax.set_yticklabels([r'${%s}$' % i for i in SE], minor=True)
        else:
            ax.yaxis.set_visible(False)

        ax.set_xlim([0,horizon])
        my_xticks = ['2010', '2011', '2012', '2013', '2014','2015','2016','2017']
        x = [0, 250, 250*2, 250*3, 250*4,250*5,250*6, 250*7]
        plt.xticks(x, my_xticks)
        ax.set_ylim([-self.dim, 1])
        ax.set_xlabel('Time Series')
        plt.tight_layout()

# %%
SE=[]
#with open('/Users/olgascrivner/Documents/CNS/BurningGlass/LIngfei/BG/skills-list-DSDE-2010-2016.txt','r', encoding = 'latin') as f:
for i in DSDE1:
        SE.append(i)

# %%
plot_events(P,horizon=-1, showDays=False, labeled=True)


#plt.savefig('hawkes-jobs-burst.png')

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.gca()
for i in range(P.dim):

    #print('y',np.zeros(len(subseq)) - i)
    subseq = P.data[P.data[:,1]==i][:,0]
    #print(i,len(subseq)) # data points X axis
    plt.plot(subseq, np.zeros(len(subseq)) - i, 'bo', alpha=0.2) #x= subseq, y = len of skills 'bo' using blue circle markers
    my_xticks = ['2010', '2011', '2012', '2013', '2014','2015','2016','2017']
    x = [0, 250, 500, 750, 1000,1250,1500, 1750]
    plt.xticks(x, my_xticks)
    ax.set_yticklabels('')
    ax.set_yticks(-np.arange(0, P.dim), minor=True)
    ax.set_yticklabels([r'${%s}$' % i for i in DSDE1], minor=True)
    #ax.yaxis.set_visible(False)

# %%
horizon = np.amax(P.data[:,0])
s = ['apache hadoop','apache hive','big data']
f, axarr = plt.subplots(6,1, sharex='col', 
                                gridspec_kw = {'height_ratios':[3,1,3,1,3,1]}, 
                                figsize=(8,5))
xs = np.linspace(0, horizon, (horizon/100.)*1000)
my_xticks = ['2010', '2011', '2012', '2013', '2014','2015','2016','2017']
x = [0, 250, 500, 750, 1000,1250,1500, 1750]
plt.xticks(x, my_xticks)
for i in range(0, 3):
            row = i * 2

            # plot rate
            r = [P.get_rate(ct, i) for ct in xs]
            axarr[row].plot(xs, r, 'k-')
            axarr[row].set_ylim([-0.01, np.amax(r)+(np.amax(r)/2.)])
            axarr[row].set_ylabel('$\lambda(t)_{%d}$' % i, fontsize=14)
              #  ax.set_yticklabels('')
   # ax.set_yticks(-np.arange(0, P.dim), minor=True)
    #ax.set_yticklabels([r'${%s}$' % i for i in DSDE1], minor=True)
            r = []

            # plot events
            subseq = P.data[P.data[:,1]==i][:,0]
            axarr[row+1].plot(subseq, np.zeros(len(subseq)) - 0.5, 'bo', alpha=0.2)

            axarr[row+1].yaxis.set_visible(False)
            ax.set_yticklabels('')
            ax.set_yticks(-np.arange(0, P.dim), minor=True)
 #           ax.set_yticklabels([r'$e_{%d}$' % i for i in range(self.dim)], minor=True)
            axarr[row].set_ylabel(r'${%s}$' % s[i])

            axarr[row+1].set_xlim([0, horizon])
